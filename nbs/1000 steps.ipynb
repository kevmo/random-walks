# %% [markdown]
# # A single random walk with 2 million steps

# %%
import random


position = 0
walk = [position]
STEPS = 2000000

for i in range(STEPS):
    step = 1 if random.randint(0, 1) else -1
    position += step
    walk.append(position)

# %%
print(position)
# Out:
# -1672

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(walk[:100])
